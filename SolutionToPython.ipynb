# %% [markdown]
# <a href="https://colab.research.google.com/github/NITianHarsh/PythonLearning/blob/main/SolutionToPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Solutions to Assignment 1

# %% [markdown]
# ## Integers_Float....

# %% [markdown]
# ###Problem 1

# %%
winPoint = 3
drawPoint = 1
lossPoint = 0

total_matches = 8
matches_win = 4
matches_loss = 3
matches_draw = 1

# %%
total_score = winPoint*matches_win + drawPoint*matches_draw + lossPoint*matches_loss

print(total_score)
# Out:
# 13

# %% [markdown]
# ### Problem 2

# %%
def fun_x(x):
  val = x**2 + 3*x - 4
  return val;

# %%
print(f'at x = 2: {fun_x(2)}')
print(f'at x = -1: {fun_x(-1)}')
print(f'at x = 1: {fun_x(1)}')
# Out:
# at x = 2: 6
# at x = -1: -6
# at x = 1: 0

# %% [markdown]
# ### Problem 3

# %%
apples = 45
oranges = 65
bananas = 30

# %%
total = apples + bananas + oranges

# %%
percent_apple = apples*100/total
percent_banana = bananas*100/total
percent_oranges = oranges*100/total

# %%
print(f'apple percent: {round(percent_apple, 2)}')
print(f'banana percent: {round(percent_banana, 2)}')
print(f'orange percent: {round(percent_oranges, 2)}')
# Out:
# apple percent: 32.14
# banana percent: 21.43
# orange percent: 46.43

# %% [markdown]
# ### Problem 4

# %%
total = 100
maths_major = 30
economics_major = 45
physics_major = 25

# %%
maths_guessed = 20
economics_guessed = 30
physics_guessed = 20

# %%
maths_accuracy = maths_guessed/maths_major *100
economics_accuracy = economics_guessed/economics_major * 100
physics_accuracy = physics_guessed/physics_major * 100
total_accuracy = (maths_guessed + physics_guessed + economics_guessed)/(maths_major + physics_major + economics_major) * 100

# %%
print(f'maths: {round(maths_accuracy, 2)}')
print(f'economics: {round(economics_accuracy, 2)}')
print(f'phyiscs: {round(physics_accuracy, 2)}')
print(f'total accuracy: {round(total_accuracy, 2)}')
# Out:
# maths: 66.67
# economics: 66.67
# phyiscs: 80.0
# total accuracy: 70.0

# %% [markdown]
# ## Loops and iterations

# %% [markdown]
# ### Problem 1

# %%
my_dict = {0:" "}
for i in range(26):
  ch = chr(ord('a') + i)
  my_dict[i+1] = ch

# %% [markdown]
# ### Problem 2

# %%
def encrypt_message(msg):
    return "".join(my_dict[len(word)] for word in msg)

# %%
encrypyted_message = ("ajsuydtbe", "", "wunjbfusnjrgut", "uhbhr", "oirun", "lpef", "", "vhejsibr", "ydtse", "qlvuusrntuos", "ijwlbutybhlsoaxh")
print(encrypt_message(encrypyted_message))
# Out:
# i need help

# %% [markdown]
# ### Problem 3

# %%
jumbled_word = ["hugdtck", "tsogbklesrawqcbjplu", "qkisrubskoaitbt", "nslaoetr", "oksinjioaendnjsdqwbh"]
print("".join(sorted(encrypt_message(jumbled_word))))
# Out:
# ghost

# %% [markdown]
# ### Problem 4

# %%
def isPerfect(num):
  my_sum = sum(x for x in range(1,num) if num%x == 0)
  if my_sum == num:
    return True
  return False

# %%
num = int(input("Enter number: "))
isPerfect(num)
# Out:
# Enter number: 124
# False

# %% [markdown]
# ## Functions & Methods

# %% [markdown]
# ### Problem 1

# %%
def get_excel_column_number(col):
  string_len = len(col) - 1;
  last = ord(col[string_len]) - ord('A') + 1
  ans = last;

  while string_len > 0:
    last = ord(col[string_len-1]) - ord('A') + 1
    ans += last*(26**string_len)
    string_len -= 1;

  return ans;

# %%
print(get_excel_column_number('BQ'))
print(get_excel_column_number('ALQ'))

# %% [markdown]
# ### Problem 2

# %%
def calculate_accuracy(actual, predicted):
    correct = 0

    for a, p in zip(actual, predicted):
        if a == p:
            correct += 1

    accuracy = (correct / len(actual)) * 100
    return accuracy

# %%
actual_labels = ['Cat','Dog','Cat','Cat','Dog','Cat','Dog','Cat','Cat','Cat',
                 'Dog','Dog','Cat','Cat','Cat','Dog','Dog','Dog','Cat','Dog']

predicted_labels = ['Cat','Dog','Cat','Cat','Dog','Cat','Dog','Cat','Dog','Dog',
                    'Dog','Dog','Cat','Cat','Cat','Dog','Dog','Dog','Cat','Cat']

print("Accuracy:", calculate_accuracy(actual_labels, predicted_labels), "%")
# Out:
# Accuracy: 85.0 %

# %% [markdown]
# ### Problem 3

# %%
def precision_recall(actual, predicted, label):
    true_positive = 0
    predicted_positive = 0
    actual_positive = 0

    for a, p in zip(actual, predicted):
        if p == label:
            predicted_positive += 1
        if a == label:
            actual_positive += 1
        if a == label and p == label:
            true_positive += 1

    precision = (true_positive / predicted_positive) * 100 if predicted_positive else 0
    recall = (true_positive / actual_positive) * 100 if actual_positive else 0

    return precision, recall

# %%
p_cat, r_cat = precision_recall(actual_labels, predicted_labels, 'Cat')
print(f"Cat Precision: {p_cat:.2f}%")
print(f"Cat Recall: {r_cat:.2f}%")
# Out:
# Cat Precision: 90.00%
# Cat Recall: 81.82%

# %%
p_dog, r_dog = precision_recall(actual_labels, predicted_labels, 'Dog')
print(f"Dog Precision: {p_dog:.2f}%")
print(f"Dog Recall: {r_dog:.2f}%")
# Out:
# Dog Precision: 80.00%
# Dog Recall: 88.89%

# %% [markdown]
# ### Problem 4

# %%
def sentence_len_counts(sentence, length):
    return sum(1 for word in sentence.split() if len(word) == length)

# %%
marvel_quote = "The world has changed and none of us can go back. All we can do is our best, and sometimes the best that we can do is to start over."
print(sentence_len_counts(marvel_quote, 5))
# Out:
# 5

# %% [markdown]
# ## Introduction to List

# %% [markdown]
# ### Problem 1

# %%
temperatures = [34, 40, 29, 33, 42, 37, 39 ]

# %%
a = temperatures.index(min(temperatures))
b = temperatures.index(max(temperatures))
temperatures[a], temperatures[b] = temperatures[b], temperatures[a]

# %%
print(temperatures)
# Out:
# [34, 40, 42, 33, 29, 37, 39]

# %% [markdown]
# ### Problem 2

# %%
prod_price_list = [400, 250, 800, 550, 600, 820, 720, 15000, 360,250,100]

# %%
def calculate_median(lis):
    lis = sorted(lis)
    n = len(lis)

    if n % 2 == 0:
        return (lis[n//2] + lis[n//2 - 1]) / 2
    else:
        return lis[n//2]

def calculate_mean(lis):
  return sum(lis)//len(lis)

# %%
print(calculate_median(prod_price_list))
print(calculate_mean(prod_price_list))
# Out:
# 550
# 1804

# %% [markdown]
# ### Problem 3

# %%
tech_companies = ['Qualcomm','Google','Apple',['Nvidia','Cisco','Samsung']]
print(tech_companies)
# Out:
# ['Qualcomm', 'Google', 'Apple', ['Nvidia', 'Cisco', 'Samsung']]

# %%
flat_list=[]
def flatten_list(tech_companies):
  for elements in tech_companies:
    if type(elements) == list:
      flatten_list(elements)
    else:
      flat_list.append(elements)

flatten_list(tech_companies)
print(flat_list)
# Out:
# ['Qualcomm', 'Google', 'Apple', 'Nvidia', 'Cisco', 'Samsung']

# %% [markdown]
# ## Introduction to string

# %% [markdown]
# ### Problem 1

# %%
def countWords(sentence):
  return sentence.count(' ')+1;

# %%
sentence = "Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation."
print(countWords(sentence))
# Out:
# 20

# %% [markdown]
# ### Problem 2

# %%
len = int(input())
print('-'*len)
# Out:
# 8
# --------

# %% [markdown]
# ### Problem 3

# %%
st = input()
def is_bridge(st):
  if st.count(' ')+1 > 1:
    return False;
  return True;
is_bridge(st)
# Out:
# sdfsg
# True

# %% [markdown]
# ### Problem 4

# %%
string= input('enter the string = ')
count_d=string.lower().count('d')
print(count_d)
# Out:
# enter the string = fdsfsdwqijd23
# 3

# %% [markdown]
# ### Problem 5

# %%
string1 = input('enter the string = ')

def isPalin(string1):
    n = len(string1)
    for i in range(n // 2):
        if string1[i] != string1[n - i - 1]:
            return False
    return True

print(isPalin(string1))
# Out:
# enter the string = asdada
# False

# %% [markdown]
# ## List Comprehension

# %% [markdown]
# ### Problem 1

# %%
house_area_price_dict = {1056 : 39, 2600 : 120 , 1520 : 95, 1200 : 50, 2700 : 200, 1100 : 40}
def predicted_price(area):
  return 0.05*area + 10

# %%
pred_price = [round(predicted_price(x), 2) for x in house_area_price_dict.keys()]
print(pred_price)
# Out:
# [62.8, 140.0, 86.0, 70.0, 145.0, 65.0]

# %%
diff = [round((y-x)**2, 2) for x, y in zip(house_area_price_dict.values(), pred_price)]
print(diff)
# Out:
# [566.44, 400.0, 81.0, 400.0, 3025.0, 625.0]

# %% [markdown]
# ### Problem 2

# %%
import math
x = [3, 9, 10, -4, -2, 1, 0, 4, 5, 7]

def sigmoid(x):
    return 1 / (1 + math.exp(-x))

# %%
ans = [round(sigmoid(a), 4) for a in x]
print(ans)
# Out:
# [0.9526, 0.9999, 1.0, 0.018, 0.1192, 0.7311, 0.5, 0.982, 0.9933, 0.9991]

# %% [markdown]
# ### Problem 3

# %%
sentence = "I have been walking and running and dancing and smiling and laughing all my life, yet it all seems pointless."
my_words = [word for word in sentence.split() if word.endswith('ing')]
print(my_words)
# Out:
# ['walking', 'running', 'dancing', 'smiling', 'laughing']

# %% [markdown]
# ### Problem 4

# %%
stop_words = {"i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself",
              "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself",
              "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that",
              "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had",
              "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because",
              "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into",
              "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out",
              "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where",
              "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no",
              "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just",
              "don", "should", "now"}

# %%
custom_stop_words = ["hello","good","morning","half","year"]

# %%
stop_words.update(custom_stop_words)

# %% [markdown]
# ## Statement_Indentations

# %% [markdown]
# ### Problem 1

# %%
date_year = int(input("year "))
date_month = int(input("month "))

quarter=0

if date_month >=1 and date_month<=3:
  quarter=1
elif date_month >= 4 and date_month <= 6:
  quarter=2
elif date_month >= 7 and date_month <= 9:
 quarter = 3
else:
  quarter =4

print(f'quarter: {quarter}')
# Out:
# year 2022
# month 5
# quarter: 2

# %% [markdown]
# ### Problem 2

# %%
locality_data = {'Name' : ['Abhinav','Sohail','Dheeraj','Rashmi','Vaishali'],
                  'Age' : [42,29,35,28,32],
                  'Sex' : ['Male', 'Male','Male','Female','Female'] ,
                  'Height' : [172,175,170,168,170],
                  'Weight' : [70,82,60,55,64]
                 }

# %%
def find_mean(lst):
  s = sum(lst)
  n = len(lst)
  return round(s/n, 2);

def find_median(lst):
    lst = sorted(lst)
    n = len(lst)

    if n % 2 == 1:
        return lst[n // 2]
    else:
        return (lst[n//2 - 1] + lst[n//2]) / 2

# %%
print(f'Mean Height is: {find_mean(locality_data['Height'])} and Median Height is: {find_median(locality_data['Height'])}')
print(f'Mean Weight is: {find_mean(locality_data['Weight'])} and Median Weight is: {find_median(locality_data['Weight'])}')
# Out:
# Mean Height is: 171.0 and Median Height is: 170
# Mean Weight is: 66.2 and Median Weight is: 64

# %%
print(locality_data['Age'][:3])
# Out:
# [42, 29, 35]

# %% [markdown]
# ### Problem 3

# %%
print("Number of classes held")
classes_held = int(input())

print("Number of classes attended")
classes_attended = int(input())

attendance = classes_attended*100/classes_held

print(f'The attendance is {round(attendance, 2)}')

if attendance >= 75:
  print('The student is alloed to sit in exam')
else:
  print("The student is not allowed")
# Out:
# Number of classes held
# 45
# Number of classes attended
# 23
# The attendance is 51.11
# The student is not allowed

# %% [markdown]
# ### Problem 4

# %%
print("Enter your marks")
marks = int(input())

if marks >80:
  print("Your grade if A")
elif marks >=60 and marks < 80:
  print("Your grade if B")
elif marks >=50 and marks < 60:
  print("Your grade if C")
elif marks >= 45 and  marks < 50:
  print("Your grade if D")
elif marks >= 25 and marks <45:
  print("Your grade if E")
else:
  print("Your grade if F")
# Out:
# Enter your marks
# 34
# Your grade if E

# %% [markdown]
# ## Tuples, Set, Dictionaries

# %% [markdown]
# ### Problem 1

# %%
temperatures = [34, 40, 29, 33, 42, 40, 39, 34, 34,33 ]

# %%
def find_mode(lst):
    freq = {}

    # frequency count
    for num in lst:
        if num in freq:
            freq[num] += 1
        else:
            freq[num] = 1

    # find max frequency
    max_freq = max(freq.values())

    # collect all modes
    modes = []
    for key in freq:
        if freq[key] == max_freq:
            modes.append(key)

    return modes
find_mode(temperatures)
# Out:
# [34]

# %%
from collections import Counter

def find_mode(lst):
    freq = Counter(lst)
    max_freq = max(freq.values())
    return [k for k, v in freq.items() if v == max_freq]

find_mode(temperatures)
# Out:
# [34]

# %% [markdown]
# ### Problem 2

# %%
list_of_tuples = [(10,20,30),(30,40,50),(50,60,70)] # 70 to 100

# %%
x = 100
list_of_tuples[-1] = (list_of_tuples[-1][0], list_of_tuples[-1][1], x)
print(list_of_tuples)
# Out:
# [(10, 20, 30), (30, 40, 50), (50, 60, 100)]

# %% [markdown]
# ### Problem 3 - solved

# %% [markdown]
# ### Problem 4

# %% [markdown]
# ## Production Grade

# %% [markdown]
# ### Problem 1

# %% [markdown]
# ### Problem 2

# %% [markdown]
# ### Problem 3

# %% [markdown]
# # Solution to Assignment 2

# %% [markdown]
# ## Module 1

# %% [markdown]
# ### 1.	Read a table from a Webpage, CSV and XLSX  to return a list of DataFrame Objects

# %%
import pandas as pd

# %%
df1 = pd.read_html()
df2 = pd.read_csv()
df3 = pd.read_excel()
lis = [df1, df2, df3]

# %% [markdown]
# ### 2.	Write a program that accepts a sentence and calculate the number of upper case letters and lower case letters.

# %%
s = input("Enter the string: ")

def readStr(s):
    lower = 0
    upper = 0

    for ch in s:
        if ch.islower():
            lower += 1
        elif ch.isupper():
            upper += 1

    return lower, upper

low, up = readStr(s)
print(f'lower are: {low} and upper are: {up}')
# Out:
# Enter the string: Hellow my name is Harsh it SDJS
# lower are: 19 and upper are: 6

# %% [markdown]
# ###3.	Write a program to shuffle and print the list [3,6,7,8] Hint : use shuffle function

# %%
import random as r
lis = [3,6,7,8]
r.shuffle(lis)
lis
# Out:
# [3, 7, 6, 8]

# %% [markdown]
# ###4.	Baby names dataset:
# * Group the dataset by name and assign to names
# *	How many different names exist in the dataset?
# *	How many different names have the least occurrences?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('baby_names.csv')
df.head()
# Out:
#    Unnamed: 0     Id     Name  Year Gender State  Count
# 0       11349  11350     Emma  2004      F    AK     62
# 1       11350  11351  Madison  2004      F    AK     48
# 2       11351  11352   Hannah  2004      F    AK     46
# 3       11352  11353    Grace  2004      F    AK     44
# 4       11353  11354    Emily  2004      F    AK     41

# %%
names = df.groupby('Name')

# %%
len(names)
# Out:
# 17632

# %%
counts = names.size()
counts[counts == counts.min()]
# Out:
# Name
# Aadarsh       1
# Aadhav        1
# Aadin         1
# Aahna         1
# Aaima         1
#              ..
# Zykeriah      1
# Zykierra      1
# Zymari        1
# Zyquavious    1
# Zyren         1
# Length: 3682, dtype: int64

# %% [markdown]
# ###5.	Ecommerce Purchase Dataset :
# * What is the average purchase price ?
# *	What were the highest and lowest purchase prices?
# *	How many people have English 'en' as their Language of choice on the website?
# *	How many people have the job title of "Lawyer"
# *	What are the 5 most common Job Titles?

# %%
df1 = pd.read_csv('/content/Ecommerce Purchases')
df1.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\r\nAlexisborough, NE ...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM
# 2                 Unit 0065 Box 5052\r\nDPO AP 27450  94 vE       PM
# 3            7780 Julia Fords\r\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\r\nNew Cynthia, TX...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
df1['Purchase Price'].mean()
# Out:
# np.float64(50.347302)

# %%
print(f' max purchase is: {df1['Purchase Price'].max()}, and min purchase is: {df1['Purchase Price'].min()}')
# Out:
#  max purchase is: 99.99, and min purchase is: 0.0

# %%
eng_user = (df1['Language'] == 'en').sum()
print(eng_user)
# Out:
# 1098

# %%
Job_user = (df1['Job'] == 'Lawyer').sum()
print(Job_user)
# Out:
# 30

# %%
top5_jobs = df1['Job'].value_counts().head(5)
print(top5_jobs)
# Out:
# Job
# Interior and spatial designer        31
# Lawyer                               30
# Social researcher                    28
# Research officer, political party    27
# Designer, jewellery                  27
# Name: count, dtype: int64

# %% [markdown]
# ###6.	Grocery Dataset :
# *	What is the price of each item?
# *	Sort by the name of the item
# *	What was the quantity of the most expensive item ordered?
# *	How many times were a Veggie Salad Bowl ordered?
# *	How many times people ordered more than one Canned Soda?
# *	For the most-ordered item, how many items were ordered?
# *	Turn the item price into a float

# %%
df2 = pd.read_csv('/content/grocery.txt', sep='\t')
df2.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
result = (
    df2.groupby('item_name', as_index=False)['item_price']
       .max()
)
print(result)
# Out:
#                                 item_name  item_price
# 0                       6 Pack Soft Drink       12.98
# 1                           Barbacoa Bowl       11.75
# 2                        Barbacoa Burrito       11.75
# 3                   Barbacoa Crispy Tacos       18.50
# 4                     Barbacoa Salad Bowl       11.89
# 5                     Barbacoa Soft Tacos       11.75
# 6                           Bottled Water       15.00
# 7                                    Bowl       22.20
# 8                                 Burrito        7.40
# 9                             Canned Soda        4.36
# 10                      Canned Soft Drink        5.00
# 11                          Carnitas Bowl       35.25
# 12                       Carnitas Burrito       18.50
# 13                  Carnitas Crispy Tacos       17.98
# 14                         Carnitas Salad        8.99
# 15                    Carnitas Salad Bowl       11.89
# ...

# %%
df2.drop_duplicates('item_name')['item_name'].sort_values()
# Out:
# 298                         6 Pack Soft Drink
# 39                              Barbacoa Bowl
# 21                           Barbacoa Burrito
# 168                     Barbacoa Crispy Tacos
# 1229                      Barbacoa Salad Bowl
# 56                        Barbacoa Soft Tacos
# 34                              Bottled Water
# 445                                      Bowl
# 510                                   Burrito
# 18                                Canned Soda
# 263                         Canned Soft Drink
# 33                              Carnitas Bowl
# 27                           Carnitas Burrito
# 554                     Carnitas Crispy Tacos
# 3750                           Carnitas Salad
# 1132                      Carnitas Salad Bowl
# 237                       Carnitas Soft Tacos
# 4                                Chicken Bowl
# 16                            Chicken Burrito
# 11                       Chicken Crispy Tacos
# ...

# %%
df2.iloc[92]['quantity']
# Out:
# np.int64(1)

# %%
df2[df2['item_name'] == 'Veggie Salad Bowl'].shape[0]
# Out:
# 18

# %%
df2[(df2['item_name'] == 'Canned Soda') & (df2['quantity'] > 1)].shape[0]
# Out:
# 20

# %%
df2[df2['order_id']==40].shape[0]
# Out:
# 3

# %%
df2['item_price'] = df2['item_price'].str.replace('$', '', regex=False).astype(float)

# %%
df2.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#    item_price
# 0        2.39
# 1        3.39

# %% [markdown]
# ###7.	Please write a program to print the list after removing delete even numbers in [5,6,77,45,22,12,24].

# %%
lis = [5,6,77,45,22,12,24]

# %%
new_lis = list(filter(lambda x: x%2 != 0, lis))
new_lis
# Out:
# [5, 77, 45]

# %% [markdown]
# ###1. Define a function which can generate a list where the values are square of numbers between 1 and 20 (both included). Then the function needs to print the first 5 elements in the list.

# %%
lis = [x**2 for x in range(1,21)]
def func(lis):
  for i in range(5):
    print(lis[i])

# %%
func(lis)
# Out:
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# ## Module 2 --> Interview Questions

# %% [markdown]
# ###Load the data set – Global SuperStore data:
# *	Q1. Which segment has the highest number of “High” order priority.
# *	Q2. Bucket the sales values (use 4 buckets - bucket 1/bucket 2 etc.) and analyze it segments wise, e.g. which segment has how many sales buckets.
#
# Conceptual:
#
# *	Q3. Write down a generator which uses yield and return, and describe the differences.

# %%
df4 = pd.read_excel('/content/Global_Superstore2.xlsx')
df4.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
df4.shape
# Out:
# (51290, 25)

# %%
df4[df4['Order Priority'] == 'High'].groupby('Segment').size().head(1).sort_values(ascending=False)
# Out:
# Segment
# Consumer    8257
# dtype: int64

# %%
df4['Sales Bucket'] = pd.qcut(
    df4['Sales'],
    q=4,
    labels=['Bucket 1', 'Bucket 2', 'Bucket 3', 'Bucket 4']
)

# %%
result = pd.pivot_table(
    df4,
    index='Segment',
    columns='Sales Bucket',
    values='Sales',
    aggfunc='count',
    fill_value=0
)

print(result)
# Out:
# Sales Bucket  Bucket 1  Bucket 2  Bucket 3  Bucket 4
# Segment
# Consumer          6642      6622      6628      6626
# Corporate         3823      3869      3860      3877
# Home Office       2358      2331      2334      2320
# /tmp/ipython-input-758/513705458.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   result = pd.pivot_table(

# %% [markdown]
# **Generator using `yield` and `return`:**
#
# ```python
# def number_generator(n):
#     for i in range(n):
#         yield i
#     return "Done"
# ```
#
# **Difference between `yield` and `return`:**
#
# * **yield**
#
#   * Produces values one by one.
#   * Pauses the function and preserves state.
#   * Can be used multiple times in a generator.
#   * Used to create generators (lazy evaluation).
#
# * **return**
#
#   * Terminates the function completely.
#   * Cannot resume execution after return.
#   * Executes only once.
#   * In generators, it raises `StopIteration` with the return value.

# %% [markdown]
# ### Problem 2
# *	Q1. Find the Quantity for each Market and each country in monthly and weekly frequency.
# *	Q2. Plot a group chart and show the category wise distribution for each region.
#
# Conceptual:
#
# *	Q3. Write down a function which will take a input of two side length of a triangle and return the mentioned angle [<DCB]

# %%
import matplotlib.pyplot as plt
grouped = (
    df4.groupby(['Region', 'Category'])
      .size()
      .reset_index(name='Count')
)

# %%
pivot_df = grouped.pivot(
    index='Region',
    columns='Category',
    values='Count'
).fillna(0)

# %%
pivot_df.plot(kind='bar', figsize=(8,5))
plt.ylabel('Count')
plt.title('Category-wise Distribution by Region')
plt.xticks(rotation=45)
plt.show()

# %%
import math

def find_angle(height, base):
    angle_rad = math.atan(height / base)
    angle_deg = math.degrees(angle_rad)
    return round(angle_deg, 2)

# %%
find_angle(4,5)
# Out:
# 38.66

# %% [markdown]
# ###2.	Write a program to check given number is prime or not

# %%
import math
def is_prime(n):
    if n <= 1:
        return False

    for i in range(2, int(math.sqrt(n)) + 1):
        if n % i == 0:
            return False

    return True

# %%
n = int(input("Enter num: "))

is_prime(n)
# Out:
# Enter num: 2323
# False

# %% [markdown]
# ### problem 5

# %%
names = [
"Ms Jane Doe (US)",
"Mr. John Smith (GB)",
"Mrs. Licey Root (NZ)",
"Dr. Jane Abbott (US)",
"Dr. Kevin Johnson (FR)",
"Sir John Paul (IN)",
"Ms. Paul/ Samantha (EN)",
"Mr. Gooch, Paul Alex (FR)",
"Fr. Agnel Joseph (AU)",
"George W. Bush Jr (US)",
"George W. Bush Sr. (US)",
"Prof John Reed (CA)",
"Mme Jeanne Glace (FR)",
"Herr Helmut Kohl (DE)"
]

# %%
countries = []
for name in names:
  name = name.split('(')[1]
  name = name[:-1]
  countries.append(name)

countries
# Out:
# ['US',
#  'GB',
#  'NZ',
#  'US',
#  'FR',
#  'IN',
#  'EN',
#  'FR',
#  'AU',
#  'US',
#  'US',
#  'CA',
#  'FR',
#  'DE']

# %%
first_names = []

for name in names:
    name = name.split('(')[0].strip()

    if ',' in name:
        first = name.split(',')[1].strip().split()[0]
    elif '/' in name:
        first = name.split('/')[1].strip().split()[0]
    else:
        parts = name.split()
        titles = ['Ms','Mr.','Mrs.','Dr.','Sir','Fr.','Prof','Mme','Herr','Ms.']

        if parts[0] in titles:
            first = parts[1]
        else:
            first = parts[0]

    first_names.append(first)

first_names
# Out:
# ['Jane',
#  'John',
#  'Licey',
#  'Jane',
#  'Kevin',
#  'John',
#  'Samantha',
#  'Paul',
#  'Agnel',
#  'George',
#  'George',
#  'John',
#  'Jeanne',
#  'Helmut']

# %%
middle_names = []
for name in names:
    name = name.split('(')[0].strip()
